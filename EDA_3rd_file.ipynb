# %% [markdown]
# <a href="https://colab.research.google.com/github/NK-cloud-hub/testrepo/blob/main/EDA_3rd_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("df_recipe_performance_machine3.csv")

# %%
# Convert timestamp column to datetime
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
# Set timestamp as index for time-based analysis
df.set_index("timestamp", inplace=True)

# %%
# Show basic info and statistics
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5523 entries, 2024-01-24 17:00:00+00:00 to 2025-03-31 23:00:00+00:00
# Data columns (total 31 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   availability                      5523 non-null   float64
#  1   operationalavailability           5523 non-null   float64
#  2   efficiency                        5523 non-null   float64
#  3   oee                               5523 non-null   float64
#  4   qualityrate                       5523 non-null   float64
#  5   runningtime                       5523 non-null   int64
#  6   mtbf                              5523 non-null   float64
#  7   mttr                              5523 non-null   float64
#  8   rejectionrate                     5523 non-null   float64
#  9   processed                         5523 non-null   int64
#  10  produce                           5523 non-null   int64
#  11  workingtime                       5523 non-null   int64
#  12  netoperatingtime                  5523 non-null   float64
#  13  effectivetimeexpectedproduction   5523 non-null   float64
#  14  internaldowntime                  5523 non-null   int64
#  15  internalstops                     5523 non-null   int64
#  16  nodatatime                        5523 non-null   int64
#  17  externaltime                      5523 non-null   int64
#  18  planneddowntime                   5523 non-null   int64
#  19  productiontimeexpectedproduction  5523 non-null   int64
#  20  induceddowntime                   5523 non-null   int64
#  21  reactiontime                      5523 non-null   int64
#  22  equipmentdowntime                 5523 non-null   int64
#  23  effectivetime                     5523 non-null   int64
#  24  designspeed                       5523 non-null   float64
#  25  avgprocessspeed                   5523 non-null   float64
#  26  maxprocessspeed                   5523 non-null   float64
#  27  minprocessspeed                   5523 non-null   float64
#  28  rank                              5523 non-null   int64
#  29  recipe                            5523 non-null   object
#  30  MachineSpeed_max                  5523 non-null   int64
# dtypes: float64(14), int64(16), object(1)
# memory usage: 1.3+ MB
# None

# %%
print("\nDescriptive Statistics:\n", df.describe())
# Out:
# Descriptive Statistics:
#         availability  operationalavailability   efficiency          oee  \
# count   5523.000000              5523.000000  5523.000000  5523.000000
# mean      87.375954                55.814160    52.578545    51.140490
# std       29.126272                28.951919    29.523813    29.532835
# min        0.000000                 0.000000     0.000000     0.000000
# 25%       93.766212                38.722222    33.158532    30.990000
# 50%      100.000000                62.138889    53.523333    51.890000
# 75%      100.000000                78.777778    78.833333    77.155000
# max      100.000000               100.000000   100.000000   100.000000
#
#        qualityrate  runningtime         mtbf         mttr  rejectionrate  \
# count  5523.000000  5523.000000  5523.000000  5523.000000    5523.000000
# mean     99.677071  1997.041463  1943.005685    80.713136            inf
# std       4.206951  1047.494625  1067.024347   248.427040            NaN
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%      99.977422  1369.000000  1189.000000     0.000000       0.000000
# 50%     100.000000  2225.000000  2171.000000     0.000000       0.000000
# 75%     100.000000  2833.000000  2813.000000     0.000000       0.000407
# max     100.000000  3595.000000  3595.000000  3600.000000            inf
#
#           processed  ...  induceddowntime  reactiontime  equipmentdowntime  \
# count   5523.000000  ...      5523.000000        5523.0        5523.000000
# mean   16686.864204  ...      1073.386203           0.0        1177.074597
# std    10232.910167  ...       839.056717           0.0         866.615397
# min        0.000000  ...         0.000000           0.0           0.000000
# 25%     9875.000000  ...       417.000000           0.0         509.000000
# 50%    16361.000000  ...       933.000000           0.0        1051.000000
# 75%    24300.000000  ...      1580.500000           0.0        1722.000000
# max    74600.000000  ...      3600.000000           0.0        3600.000000
#
#        effectivetime  designspeed  avgprocessspeed  maxprocessspeed  \
# count    5523.000000  5523.000000      5523.000000      5523.000000
# mean     3174.224697    12.062168         4.635257         7.100362
# std      1059.324533    37.317073         2.842454         4.318457
# min         0.000000     6.666667         0.000000         0.000000
# 25%      3600.000000     8.333333         2.743055         6.393330
# 50%      3600.000000     8.333333         4.544720         8.296670
# 75%      3600.000000    10.000000         6.750000         8.353330
# max      3600.000000   600.000000        20.722220       198.963330
#
#        minprocessspeed    rank  MachineSpeed_max
# count      5523.000000  5523.0       5523.000000
# mean          1.607230     1.0         47.718631
# std           2.647262     0.0         11.282555
# min           0.000000     1.0          1.000000
# 25%           0.180000     1.0         38.000000
# 50%           0.863330     1.0         50.000000
# 75%           2.286670     1.0         50.000000
# max         134.426670     1.0         77.000000
#
# [8 rows x 30 columns]

# %%
# Correlation Heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(df.drop(columns=["recipe", "rank"]).corr(),
            cmap="coolwarm", center=0, annot=False, fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# OEE(overall equipment effectiveness) Trend Over Time
oee_daily = df["oee"].resample("D").mean()

plt.figure(figsize=(14, 6))
oee_daily.plot()
plt.title("Daily Average OEE Over Time", fontsize=16)
plt.ylabel("OEE (%)")
plt.xlabel("Date")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Downtime Composition
downtime_cols = [
    "equipmentdowntime",
    "internaldowntime",
    "induceddowntime",
    "planneddowntime",
    "externaltime",
    "nodatatime"
]

downtime_sum = df[downtime_cols].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
downtime_sum.plot(kind="bar", color="tomato")
plt.title("Average Downtime Types (Seconds)")
plt.ylabel("Average Seconds per Hour")
plt.tight_layout()
plt.show()
